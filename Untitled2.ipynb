# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 1000
std = 5
std_w = 0.25

# %%
melon_width = np.random.normal(30, std ,N)
melon_height = np.random.normal(15, std ,N)
melon_weight = np.random.normal(15, std ,N)

balloon_width = np.random.normal(20, std, N)
balloon_height = np.random.normal(20, std, N)
balloon_weight = np.random.normal(0.5, std_w, N)

width = np.concatenate((melon_weight, balloon_weight))
height = np.concatenate((melon_height, balloon_height))
weight = np.concatenate((melon_weight, balloon_weight))

X = np.array([width, height, weight]).T
melon_label = np.zeros(N, dtype= 'int')
balloon_label = np.ones(N, dtype= 'int')

Y = np.concatenate((melon_label, balloon_label))

# %%
X.shape
# Out:
# (2000, 3)

# %%
Y.shape
# Out:
# (2000,)

# %%
X
# Out:
# array([[22.14384036, 22.30330467, 22.14384036],
#        [15.21773003, 10.32943871, 15.21773003],
#        [25.71473043, 17.94771721, 25.71473043],
#        ...,
#        [ 0.38824852, 15.96258928,  0.38824852],
#        [ 0.48592591, 22.81740024,  0.48592591],
#        [ 0.59880512, 15.84772701,  0.59880512]])

# %%
fig=plt.figure()
ax=plt.axes(projection='3d')

plt.scatter(X[:N, 0], X[:N ,1], X[:N ,2], c = 'orange', marker='^')
plt.scatter(X[N:, 0], X[N: ,1], X[N: ,2], c = 'blue', marker='o' )

ax.set_xlabel('width')
ax.set_ylabel('height')
ax.set_zlabel('weight')
# Out:
# Text(0.5, 0, 'weight')
